# %% [markdown]
# # 01. Исследование данных
#
# Исследование загруженных сейсмических каталогов: распределение по времени, магнитуде и географии.

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Загружаем объединённый каталог (если он уже создан)
catalog_path = Path('../data/processed/unified.csv')
if catalog_path.exists():
    df = pd.read_csv(catalog_path)
    print(f'Загружено событий: {len(df)}')
    print(df.head())
else:
    print('Каталог не найден. Запустите скрипт сбора данных:')
    print('  python -c "from src.curator import USGSFetcher; f=USGSFetcher(); f.fetch()"')
